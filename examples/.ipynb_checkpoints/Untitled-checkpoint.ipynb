# %%
from network_simplex import Node, Arc, Network

# %%
Nodo1 = Node(id='N1', balance=8)
Nodo2 = Node(id='N2', balance=-8)

# %%
arco1 = Arc(id = 'N_1 -> N_2' , 
                tail = 'N1',
                head = 'N2', 
                cost = 50,
                flow =  20)

arco2 = Arc(id = 'N_2 -> N_1' , 
                tail = 'N2',
                head = 'N1', 
                cost = 50,
                flow =  20)

# %%
Lista_de_Nodos = [Nodo1, Nodo2]
Lista_de_arcos = [arco1, arco2]
Red1 = Network(Lista_de_Nodos, Lista_de_arcos)

# %%
Red1.arcs['N_1 -> N_2']
# Out:
# Arc(id='N_1 -> N_2', tail='N1', head='N2', cost=50, flow=20, artificial=False)

# %%
Network.nodos = {'N1': Nodo1, 'N2':Nodo2

# %%
Nodo1.id
# Out:
# 'N1'

# %%
# Out:
# [Node(id='N1', balance=8), Node(id='N2', balance=80)]

# %%
arco_ij.flow = 21

# %%
arco_copia = arco_ij.copy()

# %%
arco_copia.flow = 30

# %%
arco_ij
# Out:
# Arc(id='N_i -> N_j', tail='N1', head='N2', cost=50, flow=21, artificial=False)

# %%
Nodo1.balance = 5
# Out:
# ---------------------------------------------------------------------------
# FrozenInstanceError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 Nodo1.balance = 5
#
# File <string>:4, in __setattr__(self, name, value)
#
# FrozenInstanceError: cannot assign to field 'balance'

# %%
{'N1':Nodo1}
# Out:
# {'N1': Node(id='N1', balance=8)}
